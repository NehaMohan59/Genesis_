# %% [markdown]
# # Self Consistency Prompting
#
# One of the more advanced techniques in prompt engineering is self-consistency, introduced by `Wang et al. (2022)`.
#
# This method seeks to improve upon the traditional greedy decoding typically used in chain-of-thought (CoT) prompting.
#
# The core concept involves sampling multiple diverse reasoning paths through few-shot CoT and leveraging these variations to determine the most consistent answer. The technique  enhances the effectiveness of CoT prompting, particularly for tasks requiring arithmetic and commonsense reasoning.
#
# ## References:
# * [Wang et al. (2022)](https://arxiv.org/abs/2203.11171)

# %% [markdown]
# ## Running this code on MyBind.org
#
# Note: remember that you will need to **adjust CONFIG** with **proper URL and API_KEY**!
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/GenILab-FAU/prompt-eng/HEAD?urlpath=%2Fdoc%2Ftree%2Fprompt-eng%2Fself_consistency.ipynb)

# %%
##
## ZERO SHOT PROMPTING
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding  Prompt, simulating inbounding requests from users or other systems
MESSAGE = "What is 984 * log(2)"

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates

## @TODO 
PROMPT = MESSAGE 

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="ollama",
                         model="llama3.2:latest", 
                         prompt=PROMPT, 
                         temperature=1.0, 
                         num_ctx=100, 
                         num_predict=100)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)
if time: print(f'Time taken: {time}s')
# Out:
# {'model': 'llama3.2:latest', 'prompt': 'What is 984 * log(2)', 'stream': False, 'options': {'temperature': 1.0, 'num_ctx': 100, 'num_predict': 100}}
# To calculate the value of 984 × log(2), we need to first find the logarithm of 2.
#
# The common logarithm (base 10) of 2 is approximately 0.30103.
#
# Now, multiply 984 by this value:
#
# 984 × 0.30103 ≈ 296.83
# Time taken: 9.131s

# %%
##
## ZERO SHOT PROMPTING
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding  Prompt, simulating inbounding requests from users or other systems
MESSAGE = """You are an advanced study companion designed to help in learning SQL and Python, solving assignments, "
    "and improving conceptual understanding. Your role is to provide:\n"
    "1. *Step-by-step explanations* of SQL and Python concepts with real-world examples.\n"
    "2. *Interactive coding exercises* to reinforce learning.\n"
    "3. *Guidance on solving assignments*, including breaking down problems and explaining solutions.\n"
    "4. *Project ideas* to apply SQL and Python knowledge in real-world scenarios.\n"
    "5. *Study strategies and time management tips* for effective learning.\n"
    "6. *Debugging help*, explaining errors in SQL and Python code and how to fix them.\n"
    "Format responses with clear sections, bullet points, and code snippets where necessary."""

ADDITIONAL = """Generate ten independent responses and determine the most consistent, well-reasoned explanation. "
             "Ensure answers follow a structured format, include examples, and prioritize clarity. "
             "Provide multiple approaches when solving problems for deeper understanding."""

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates

## @TODO 
PROMPT = MESSAGE + ADDITIONAL

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="ollama",
                         model="llama3.2:latest", 
                         prompt=PROMPT, 
                         temperature=0.7, 
                         num_ctx=200, 
                         num_predict=1500)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)
if time: print(f'Time taken: {time}s')
# Out:
# {'model': 'llama3.2:latest', 'prompt': 'You are an advanced study companion designed to help in learning SQL and Python, solving assignments, "\n    "and improving conceptual understanding. Your role is to provide:\n"\n    "1. *Step-by-step explanations* of SQL and Python concepts with real-world examples.\n"\n    "2. *Interactive coding exercises* to reinforce learning.\n"\n    "3. *Guidance on solving assignments*, including breaking down problems and explaining solutions.\n"\n    "4. *Project ideas* to apply SQL and Python knowledge in real-world scenarios.\n"\n    "5. *Study strategies and time management tips* for effective learning.\n"\n    "6. *Debugging help*, explaining errors in SQL and Python code and how to fix them.\n"\n    "Format responses with clear sections, bullet points, and code snippets where necessary.Generate ten independent responses and determine the most consistent, well-reasoned explanation. "\n             "Ensure answers follow a structured format, include examples, and prioritize clarity. "\n             "Provide multiple approaches when solving problems for deeper understanding.', 'stream': False, 'options': {'temperature': 0.7, 'num_ctx': 200, 'num_predict': 1500}}
# Here are the ten independent responses with a clear structure, bullet points, code snippets, and explanations:
#
# **Response 1: Introduction to Debugging**
#
# ### What is Debugging?
#
# Debugging is the process of identifying and fixing errors in computer code.
#
# *   **Why is debugging important?**
#     *   Debugging ensures that software or code functions correctly and efficiently.
#     *   It helps prevent bugs from causing system crashes, data loss, or security breaches.
#
# ### How to Start Debugging
#
# 1.  **Use a Debugger**: A debugger is a tool that helps you identify and fix errors in your code.
# 2.  **Run Your Code**: Run your code as it normally would, but with the debugger enabled.
# 3.  **Analyze the Error Message**: Study the error message provided by the debugger to understand what's going wrong.
#
# **Code Snippet: Basic Debugger Example**
# ```python
# import pdb
#
# def add(a, b):
#     pdb.set_trace()  # This will stop execution at this point
#     return a + b
#
# result = add(2, 3)
# print(result)  # Output: 5
# ```
# 3.  **Check Your Variables**: Make sure your variables are in the correct scope and have the expected values.
# 4.  **Test Small Changes**: Gradually make small changes to your code to see if that resolves the issue.
#
# **Example Use Case:** Debugging a Simple Calculator Program
#
# Suppose we want to create a simple calculator program that takes two numbers as input and returns their sum. However, when we run the program, it keeps returning an incorrect result. We can use the debugging techniques outlined above to identify the source of the problem.
#
# Here's a sample code for the calculator program:
# ```python
# def add(a, b):
#     return a + b
#
# result = add(2, 3)
# print(result)  # Output: ???
# ```
# To debug this program, we can start by running it with different inputs to see if we can identify any patterns. We notice that the result is incorrect when both inputs are large numbers.
#
# Next, we can use a debugger or print statements to inspect the variables and values involved in the calculation. For example:
# ```python
# def add(a, b):
#     return a + b
#
# a = 2
# b = 3
# print("a =", a)
# print("b =", b)
# result = add(a, b)
# print("Result:", result)
# ```
# This reveals that the issue is with the addition operation itself. We can then try to debug the `add` function individually.
#
# After debugging the `+` operator, we find that it's working correctly. The problem lies in the way the inputs are being passed to the function. We realize that the inputs are not integers but rather floating-point numbers due to a previous operation in the code.
#
# To fix this issue, we need to cast the inputs back to integers before adding them together. Here's how we can do it:
#
# ```python
# def add(x, y):
#     return x + y
#
# # Example usage:
# x = 3.5  # floating-point number
# y = 2.7  # floating-point number
# result = int(add(x, y))  # cast result back to integer
# print(result)  # prints: 6
# ```
#
# Now we have a function that correctly adds two numbers together and returns the result as an integer.
#
# Note: If you want to allow for decimal points in your input numbers, you might need a more sophisticated solution.
# Time taken: 62.149s
